# %%
# Install aws cli
https://aws.amazon.com/cli/

# configure aws by running
aws configure

# nano ~/.aws/credentials
[default]
aws_access_key_id = AKIA23RAQSIX37H74ZHE
ws_secret_access_key = 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

https://746318762543.signin.aws.amazon.com/console
Password
plyEu'R2vv^yZf1

# %%
import boto3
client = boto3.client('s3')
client.list_objects(Bucket="collide-raw-data")
# Out:
# {'ResponseMetadata': {'RequestId': 'R7RBT98S2V5RSRQQ',
#   'HostId': 'zcQk3iYGtm9irQMxfy0ShxiwI8hb9dsaKuw8yLNrmhuRqvYIJygXwKXyd34aLNyCk/9IDAUNM0A=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'zcQk3iYGtm9irQMxfy0ShxiwI8hb9dsaKuw8yLNrmhuRqvYIJygXwKXyd34aLNyCk/9IDAUNM0A=',
#    'x-amz-request-id': 'R7RBT98S2V5RSRQQ',
#    'date': 'Sun, 13 Nov 2022 20:09:05 GMT',
#    'x-amz-bucket-region': 'us-west-2',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 1},
#  'IsTruncated': True,
#  'Marker': '',
#  'Contents': [{'Key': 'data/Communication_DpohExport.csv',
#    'LastModified': datetime.datetime(2022, 11, 13, 18, 35, 8, tzinfo=tzutc()),
#    'ETag': '"ceacb23251910c0179851172369ba821-2"',
#    'Size': 32609641,
#    'StorageClass': 'STANDARD',
#    'Owner': {'DisplayName': 'benwelwood',
#     'ID': '546b63fb67be37979b48ee04aa4424012ad9cfae0df9100ed38828186c7ea4d1'}},
# ...
